# %% [markdown]
# ### Week 10 | Natural Language Processing(NLP) using Naive Bayes, to predict the sentiment of Tweets
# <hr>
# ## Learning Objectives
# At the end of this lesson, you will be able to:
#
# - Understand that Naive Bayes classifier is a simple classifier that classifies based on the probabilities of events
#
# - Used Naive Bayes to perform classifying of texts into certain categories
#
# - Understand how to express the required probability of a category given a sentence into a fraction format using Naive Bayes
#
# - Know that the denominator can be ignored since they are the same for all categories
#
# - Apply pandas `groupby` function to calculate the right side of the numerator, which is the probability of each categories
#
# - Identify that the left hand side of the numerator needs to be split into individual words, since it is unlikely that the sentence to be predicted appears in the training data, hence the probability of the sentence given the category will be zero
#
# - Apply `CountVectorizer` from `sklearn` to find the list of word frequencies, in order to find the individual word probabilities in a given category
#
# - Remember to use `Laplace Smoothing` to fix the problem of the entire numerator becoming zero due to a single word probability being zero. This is possible if the word does not appear in the training data
#
# - Understand how to combine the left and right hand side of the numerator to give the required probability of each category given a sentence to be predicted
#
# - Use these probabilities of predict the category of the given sentence
#
# - Credits:
#  1. https://medium.com/analytics-vidhya/naive-bayes-classifier-for-text-classification-556fabaf252b
#  2. https://www.kaggle.com/c/tweet-sentiment-extraction/

# %% [markdown]
# ## Twitter sentiment extraction
# - "My ridiculous dog is amazing." [sentiment: positive]
#
# - With all of the tweets circulating every second it is hard to tell whether the sentiment behind a specific tweet will impact a company, or a person's, brand for being viral (positive), or devastate profit because it strikes a negative tone.
# - Disclaimer: The dataset for this competition contains text that may be considered profane, vulgar, or offensive.
# - Each row contains the text of a tweet and a sentiment label. In the training set you are provided with a word or phrase drawn from the tweet (selected_text) that encapsulates the provided sentiment.
# - The columns are:
#  1. textID - unique ID for each piece of text
#  2. text - the text of the tweet
#  3. selected_text - [train only] the text that supports the tweet's sentiment
#  4. sentiment - the general sentiment of the tweet
# - Your task will be to identify the sentiment(neutral, positive, negative), given the tweet text.

# %%
import pandas as pd
df = pd.read_csv("train.csv")
df = df.dropna()
df.head(10)
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
# 5  28b57f3990  http://www.dothebouncy.com/smf - some shameles...
# 6  6e0c6d75b1  2am feedings for the baby are fun when he is a...
# 7  50e14c0bb8                                         Soooo high
# 8  e050245fbd                                        Both of you
# 9  fc2cbefa9d   Journey!? Wow... u just became cooler.  hehe....
#
#                                        selected_text sentiment
# 0                I`d have responded, if I were going   neutral
# 1                                           Sooo SAD  negative
# 2                                        bullying me  negative
# 3                                     leave me alone  negative
# 4                                      Sons of ****,  negative
# 5  http://www.dothebouncy.com/smf - some shameles...   neutral
# 6                                                fun  positive
# 7                                         Soooo high   neutral
# 8                                        Both of you   neutral
# 9                       Wow... u just became cooler.  positive

# %% [markdown]
# ## Naive Bayes theorem
# - Based on the Naive Bayes theorem, given a text "The company is going bankrupt", we need to find out what is the probability of the sentiment `neutral`, `positive`, `neutral`. i.e we need to compare the following probabilities:
#  1. P(neutral|The company is going bankrupt)
#  2. P(positive|The company is going bankrupt)
#  3. P(negative|The company is going bankrupt)
# - Using the Naive Bayes theorem, the above can be written as,
#  1. [P(The company is going bankrupt|neutral) * P(neutral)] / P(The company is going bankrupt)
#  2. [P(The company is going bankrupt|positive) * P(positive)] / P(The company is going bankrupt)
#  3. [P(The company is going bankrupt|negative) * P(negative)] / P(The company is going bankrupt)
# - The denominator for the three equations are all the same, hence we just need to compare to numerator. i.e
#  1. [P(The company is going bankrupt|neutral) * P(neutral)]
#  2. [P(The company is going bankrupt|positive) * P(positive)]
#  3. [P(The company is going bankrupt|negative) * P(negative)]
# - Let us now look at the right side of the numerator above. To count P(neutral), P(positive), P(negative), we use the pandas dataframe `groupby` function.

# %%
total_count = df.count()[0]
group_count = df.groupby('sentiment').count()
negative_prob = group_count.iloc[0][0] / total_count
neutral_prob = group_count.iloc[1][0] / total_count
positive_prob = group_count.iloc[2][0] / total_count
print(negative_prob, neutral_prob, positive_prob)
group_count
# Out:
# 0.2831513828238719 0.40454876273653567 0.3122998544395924
#            textID   text  selected_text
# sentiment
# negative     7781   7781           7781
# neutral     11117  11117          11117
# positive     8582   8582           8582

# %% [markdown]
# ## Probability of the tweet given the sentiment
# - We have to tackle the issue that the tweet may not appear in the the sentiment group within the training set. In this case, the probability will be zero, if the tweet did not appear in any of the classes in the training set.
# - Hence, we will split the tweet into words, assuming that every word in the tweet is independent of the other ones. Instead of looking at the entire tweet sentence, we will be analysing the individual words.
# - Let us now look at the left side of the numerator above:
#  1. P(The company is going bankrupt|neutral) = P(The|neutral) * P(company|neutral) * P(is|neutral) * P(going|neutral) * P(bankrupt|neutral)
#  2. P(The company is going bankrupt|positive) = P(The|positive) * P(company|positive) * P(is|positive) * P(going|positive) * P(bankrupt|positive)
#  3. P(The company is going bankrupt|negative) = P(The|negative) * P(company|negative) * P(is|negative) * P(going|negative) * P(bankrupt|negative)
# - In short, what we are trying to calculate is P(word|sentiment) = Number of times the word appears in the sentiment class / total number of words in the sentiment class
# - To find the total number of words in the sentiment class, we can use sklearn CountVectorizer. This gives us the Term-document Matrix (TDM), which is the list of word frequencies.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# List of the selected_text for which the sentiment is negative
negative_docs = [row['selected_text'] for index,row in df.iterrows() if row['sentiment'] == 'negative']
negative_docs
# Out:
# ['Sooo SAD',
#  'bullying me',
#  'leave me alone',
#  'Sons of ****,',
#  'DANGERously',
#  'lost',
#  'Uh oh, I am sunburned',
#  '*sigh*',
#  'sick',
#  'onna',
#  'I`m sorry.',
#  '.no internet',
#  'Power back up not working too',
#  'well so much for being unhappy for about 10 minute',
#  'miss',
#  'soooooo sleeeeepy!!!',
#  'SUCKKKKKK',
#  'dont like go',
#  'd I`m not thrilled at all with mine.',
#  'it is ****...u have dissappointed me that past few days',
#  'hurts',
#  'Torn ace of hearts',
#  'i lost all my friends, i`m alone and sleepy..',
#  'I give in to easily',
#  'jealous..',
#  'BADDD.',
#  'I am sooo tired',
#  'Sick.',
#  ', sorry guys',
#  'i miss you bby',
#  'tired',
#  'freaked',
#  'unfortunately',
#  'horrible,',
#  'busy',
#  'I don`t feel confident',
#  'sad.',
#  'Not looking forward',
#  'Poor you',
#  'not well',
#  'painful.',
#  'sad?',
#  'missed all the awesome weather,',
#  'terrible!',
#  'Unfortunatley,',
#  'That sucks, tho.',
#  'Hate fighting',
#  'Car-warmed Sprite tastes like sore throat',
#  'hate',
#  'i don`t like the other ones.',
#  'Bugger. forgot I still have washing in my machine',
#  '.really bad',
#  'brutal',
#  'boring',
#  'messed',
#  'NOT THE SECRET NAMEREBECCA PLEASE',
#  'miss',
#  'illness',
#  'sad',
#  'sick!',
#  'oww',
#  'WHAT ABOUT ME ??  I VOTE EVERY DAY FOR YOU !!!!!',
#  'This diet is killing me',
#  'bored..',
#  'lost my voice',
#  'hate',
#  'I AM SUCH A CREEPER  I feel disappointed because of it. **** my cyberstalking skills   the internet = no more privacy',
#  'headache',
#  'Ew traffic',
#  'I hate not having a bike..',
#  'This is worse than taxes.',
#  'I`m not sleeping at all un',
#  'Seriously,',
#  'not going to well!',
#  'g harmed',
#  'depressed',
#  'sick.',
#  'sorry',
#  'You know your neck is jacked up when you are forced to pay for parking bc you can`t turn you head to parallel park in the free spaces...',
#  'miss',
#  'chocked',
#  'm worried',
#  'Im not bannished.',
#  'I have missed them',
#  'Ship. I`m stuck.',
#  'shame',
#  'Definitely pinched a nerve.',
#  'exhausting!',
#  'Sorry',
#  'im sad it very hurts',
#  'I`m broke',
#  'now a migraine.',
#  '?sucks!?..',
#  'I Miss Daddy and Mommy',
#  'officially depressed',
#  'That sucks!',
#  'bored',
#  'I am lost.',
#  'bad',
#  'Am hopeless at everything else',
#  'Sorry',
#  'stuck',
#  'dang',
#  'i missed all ur tweets',
#  'Damnit all. That sucks.',
#  'this is sooo crazy',
#  'some stupid ****',
#  'No fun',
#  'I feel your pain.',
#  'Sadly',
#  'aww I miss driving',
#  'that`s not good',
#  'sorry  friends',
#  'My sunburn is peeling,',
#  'I don`t have no one to cuddle with..',
#  'hate',
#  '.sorry',
#  'dying',
#  'stupid job',
#  'Dosen`t Want To',
#  'passed away',
#  's I just don`t entertain him :/',
#  'kill me',
#  'both electronic keys stopped working. there is no keyhole!',
#  'poor tony',
#  'I don`t really feel like',
#  'No waterfront anymore',
#  'feeling like poop!',
#  'then you cry ...',
#  'I don`t want to sit at home',
#  'dammit',
#  'Still jealous',
#  'Me at Forever 21  Ethan couldn`t be there',
#  'SAD',
#  'not easy!',
#  'Bouncing Rush makes me feel nauseous',
#  'playing singstar without my fave duetter',
#  'That`s just weird... :\\',
#  'That`s NOT cool',
#  'lacking,',
#  'swollen.',
#  'Don`t act like u don`t know.',
#  '! I`m scared of him',
#  'missing',
#  'mean!',
#  'not doing so good,',
#  'Missing',
#  'stuck',
#  'sad.',
#  'Sorr',
#  'live in poverty.',
#  'not going well',
#  'I miss it there',
#  'wack.',
#  'd there wasn`t a chance',
#  'Hates',
#  'traumatizing',
#  'fail)',
#  'im allergic to cats! my tonsils get swollen and they hurt  what do i dooo?!',
#  '. Tomorrow will be tough!',
#  'miss',
#  'i am living in ignorance',
#  'AWWWW  we`re gonna miss you!',
#  '. Sorry',
#  'dammit',
#  'sick and sad ..',
#  'Really wishes he had some spare cash to buy the new Punch Out for Wii',
#  'not going',
#  'So sorry',
#  'Can`t sleep..',
#  'sad.',
#  'PAIN.',
#  'Stupid',
#  'Shopped til i dropped....come bac sunshine i miss u',
#  'hard',
#  'terrible headache and super swollen and puffy eyes! i dont think im going out today.ugh!',
#  'slowest train ever,',
#  'I don`t think I`ve ever been so tierd in my life.U',
#  'why doesnt he want me anymore',
#  'bad hair day',
#  'headache',
#  'sorry',
#  'huh?',
#  'Stupid',
#  'I didn`t want to tell you but I think it`s your body odour',
#  'bad',
#  'missed',
#  'Unfortunately',
#  'tease,',
#  'bad',
#  'no answer back.',
#  'I`m kinda o sick n tired',
#  'boo.',
#  'missed out',
#  'ugh! These **** tonsils.',
#  'lost',
#  'though that isn`t going so well.',
#  'im back to this z-index problem...again',
#  'so bored at work...',
#  'hating',
#  'sucks!!',
#  'sorry',
#  'Not available in my area',
#  'cramps',
#  'FML',
#  'grouchy',
#  'worse.',
#  'my inbox is still empty',
#  'I`m such a rebel!',
#  '.i`m sorry',
#  'lost',
#  'That was stone cold   Crazy.',
#  '.no one will help me',
#  'oh sorry! not getting all my replies  nothing against you.',
#  'omg i wanted to slap her.',
#  'mad',
#  'fail at life sometimes.',
#  'doesn`t that look fab,',
#  'terrible',
#  'irrelevant.',
#  'I`m too sick to go outside',
#  'bad',
#  'screwed',
#  'just got laid off. Lots of people becoming unemployed',
#  'i never knew a dentention was so hard',
#  'my nail broke  I haaaaaaaaate',
#  'IS disappointing',
#  '. I hope Avalina isn`t a dud!',
#  'hates',
#  'Flap-a-taco was nice until the plebs came in.',
#  't sucks',
#  'sore head',
#  'stupid',
#  'I don`t think I am, my sisters refusn to get me a ticket now.',
#  'nooooo its raining..',
#  'i am completely lost.',
#  'silly',
#  'beasted',
#  'UNSALVAGEABLE',
#  'ended up inventing my own.',
#  'seems to have disappeared out of my life',
#  '****,',
#  'aww',
#  'nothing fair',
#  'i`m going to fail this final.',
#  'how sad! are you saying that I`m fat?  *tears*',
#  'can`t find it anywhere!',
#  'i have a major headache',
#  'Stupid me,',
#  'sad.',
#  'expensive.',
#  'So tired &',
#  'Mad tired. But it`s the hols! I miss chomp chomp terribly!',
#  'Missing',
#  'It just had to rain on me',
#  'i`m a victim',
#  'i would slip and fall..',
#  'a stop',
#  'but I feel sorry for Marcus though.',
#  'can`t believe',
#  'sorry ba',
#  'reupload the **** thing again',
#  'rough',
#  'Im too late... Hes gone',
#  'lost my internet signal',
#  'sorry',
#  'blood everywhere!!!',
#  'hurt my arm.',
#  '****',
#  'tiiiiiiired! Going to bed!',
#  'keeps getting such delayed responses. why is my internet so messed up?!',
#  'sad.',
#  'Sadly, that`s not too often',
#  'The sun is not cool',
#  '...  that was meeeaaannn.',
#  'so sadly',
#  'my bad',
#  'forgot',
#  'poorly',
#  'I won`t have a chance later.',
#  'SHUT YOUR FACE!',
#  'I`m really getting sick ugh',
#  'stalkerishly',
#  's disappointing',
#  '****',
#  'mad the rain got me..',
#  'i dont feel very good',
#  'excuse',
#  'I`m afraid.',
#  'I`m not having the best day',
#  'just couldn`t remember!!',
#  'Work in that heat is horrible !',
#  'isn`t easy to find',
#  '.just not lucky, never have been.',
#  'Taking care of yucky stuff.',
#  'lame',
#  'cry',
#  'I`m tired,',
#  'not good.',
#  'very bad.',
#  'I scared',
#  'bad',
#  'Its prob cuz I don`t really like sleeping in late, even if I tried.',
#  't I`m still stick.',
#  'lost',
#  '****',
#  'My throat is killing me',
#  'bloody',
#  'o itchy',
#  'waste',
#  "'accidentally'",
#  'sad me',
#  'SUCKS,',
#  'has heart burn',
#  'afraid',
#  'hard',
#  '.I`ve become poor again',
#  'No internet there.',
#  'loosing',
#  'tired?',
#  'painful',
#  'miss yall',
#  'i`m all alone',
#  'sad!',
#  'And i freakin miss anthony  ugh today kinda sucks.',
#  's super sad',
#  'breaks my heart.',
#  'terrible',
#  'problem',
#  'E EXPENSIVE',
#  'so sorry',
#  'is sad th',
#  'Poor',
#  'o can`t work that one out  pain in the **** them spammers',
#  '**** it. Totally gutted',
#  'I don`t think I like',
#  'tan',
#  'The chances of us falling in love are getting fewer and fewer.',
#  'fusterated',
#  'afraid',
#  'bad',
#  'jealous',
#  'I`m SO jealous',
#  'I`m ill',
#  '..poor thing.',
#  'e such a nasty display picture',
#  'having fever',
#  'Sick. Feel like jello, can`t talk, and delirious.',
#  'It`s teddy-chucking time',
#  'I miss my lappy.',
#  'sux,',
#  'sick',
#  'my arms hurt!',
#  'SO HUNGRY!',
#  'oh no!!!',
#  'Miss Cauzinhoooo already',
#  'sorry',
#  'missed',
#  'You are so weird.',
#  'hurts',
#  'lost',
#  'urgh',
#  'my car wont start.......',
#  'canceled.',
#  'The people get so much meaner to you.',
#  'problem',
#  'FAILlllllllll',
#  'hurt to',
#  '! sadly',
#  'noone wants to talk to me  lol',
#  'so very irratated',
#  'Yeah, I went to bed at 4 and I had to be up at 6. :[',
#  'suck',
#  'wtf',
#  'so emotional.',
#  'i`ll have to wait..',
#  'I don`t want her dressed up th',
#  'I`m lost',
#  'but not as much,',
#  'underpriveledged',
#  'e swine flu',
#  'can`t',
#  'because no one ever understands me....',
#  'I overslept  headache',
#  'too late.',
#  'I wasn`t feeling it',
#  'hard',
#  'hurts',
#  's feel guilty',
#  'i really cant take this.',
#  'bad weather .. weird summer!',
#  'ugh I`m not doin too good',
#  'it wont let me vote for some reason',
#  'miss',
#  'kill',
#  'it breaks my heart',
#  'I can`t believe I`',
#  'made me just shake my head',
#  'Boring',
#  'sad',
#  '.  this SUCKS',
#  'haven`t been working for me all day....',
#  'Epicfail',
#  'i`m freezing in math class!',
#  'endure',
#  'money is all gone!',
#  'quashed',
#  'die',
#  'ohhh please',
#  'falling apart.',
#  'Slept at my parents the bed was hard as a rock now my back feels like a rock',
#  'don`t want to work',
#  's not lettin me vote 4 them',
#  'ugh!',
#  'miss',
#  'I hate that I can be a messy eater.',
#  'hurts',
#  'wrong',
#  '. it should be recoverable.',
#  'this dude looks well `ard! He puts me to shame...',
#  'omg i miss you so muuch',
#  'has stuff to do but refuses to do them.  :[',
#  'one beat up little girl. Not a good day on',
#  'I do not mean to laugh but a little giggle did come out - sorry',
#  'No one wants to sit with me',
#  '5 seasons that`s it? Sorry just noticed in ur previous update. My sis isn`t gonna be happy',
#  'I miss rollerblading down Shoreline.',
#  'crampin`',
#  'spamming',
#  'sad',
#  'Don`t worry.',
#  'I really am insane.',
#  '.it`s expensive!',
#  'i cant figure it out.',
#  'Really missing hockey already.',
#  'Never ever',
#  'dismal',
#  'canceled',
#  'miss',
#  'Dryer labeled electric but is gas   GRRR.  Now we have 2 load it up tomorrow 2 return',
#  'I`m so sad, really really sad',
#  'inflammed',
#  'I miss him.',
#  'bad',
#  ', so sad',
#  'pissed',
#  "oy, im such a nerd..im writin 2 no1 cuz no1 is followin me  i mean lik sum1 was but their account was deleted due to 'strange activities'",
#  'dragged',
#  '?  not good enough',
#  'Stupid',
#  'They`re mental.',
#  'rotten',
#  'headed to the hospital. i can`t take the pain anymore',
#  'jealous.',
#  'Bored out of my mind!  LOL',
#  'difficult',
#  'Ugh',
#  ', awfully',
#  'i cant sleep',
#  'I`m very upset right now,',
#  'so sad',
#  'fail',
#  'anxiety',
#  'miss',
#  'copy & paste **** **** tosser piss flap a 10000000000 times !!!',
#  'hurts',
#  'not treating me well so far.',
#  'tired',
#  'missed',
#  'One problem: it wasn`t me.',
#  'i don`t think i`d like it',
#  'ruined',
#  'sorry',
#  'sucks!',
#  'I hope u r not disappointed yet',
#  'm still melting and im in the house in the shade  its not fair.',
#  't kills',
#  'worst',
#  '..bein sober jst wnt b as fun!',
#  'lazy',
#  's unfortunately',
#  'ouuuuuuuuuchhhhhhhh, still hurting from the Barca spanking',
#  'but I don`t think I can get there',
#  '. Apologies to all my supporters.',
#  'ugh',
#  'oops',
#  'Dang',
#  ', sorry',
#  'TOO MANY ASSIGNMENTS!',
#  'lost a follower',
#  'but this little boy still makin me  work during the storm!!!',
#  'Things aren`t just as easy and simple as they seem to be.',
#  's on twitter for the second day running. This is what study leave does to me! If only my car were in one piece',
#  'Unfortunately not yet,',
#  'hurts..',
#  'wish I could afford',
#  'hangover',
#  'My attempts at writing tonight seem to be failing.',
#  'Very bad things..',
#  'die',
#  'Sorry',
#  '? made me jealous',
#  'In pain,, poor me, I HATE THE SUN',
#  'boring',
#  'I can`t  has blocked me.  I can`t even reques',
#  'frustrated',
#  '****',
#  'horrible.',
#  'my tv on demad isnt working right and my internet is SUPER slow',
#  'distorted',
#  'I AM SLEEEEEPPYYYYYY!!!!!!!!',
#  'she`s gone   I miss my kay way already',
#  'Missing nathan and the bccg already.',
#  'walking in the cold **** water',
#  'i don`t like it',
#  'bust.',
#  'fail..',
#  'w she won`t be awesome at all',
#  'sucks',
#  'you suck',
#  'The case for my iPod Touch is literally falling apart.  So junk',
#  'I dont care who gets mad. I like speaking my mind. Im alreadt crazy so it helps me not go off da deep edge! **** u!',
#  'throat infection',
#  'I cant to sleep an',
#  'Please accept our apologies for the inconvenience!',
#  't boring',
#  'gaahhhh!',
#  'little sad th',
#  'oops just unfollowed everyone!  anywayz, will build my Twitter Empire.... again....',
#  'scary',
#  'feeling the beginnings of a sore throat',
#  'I **** it.',
#  'bgt was absolutely excruciating to watch...poor girl.',
#  'oops,',
#  'soo sick. i hate my life',
#  'I hate wa',
#  'ruined',
#  'suck',
#  ', I feel bad for everyone in NKorea.',
#  'Feeling so rough today,',
#  'Still soo tired..',
#  'sucks',
#  'miss',
#  'missing',
#  'bored',
#  'mistake.',
#  '**** slow',
#  'inflating',
#  'I`m so down again.',
#  'chai latte is not good',
#  'I`m under the dryer.',
#  'hyper',
#  'bed. with stomach ache',
#  'my computer is being stupid and wont let me vote  . if i could i would vote for u.',
#  'miss',
#  'too bad no',
#  'm impatient',
#  'annoying',
#  'such a low budget video',
#  'fam is not appreciating you like they should.',
#  'is still sick',
#  '****',
#  'miss',
#  'sore',
#  'jealous',
#  'sorry for the late reply',
#  'miss my best friend',
#  'Sorry',
#  'so low? No',
#  'sad',
#  'up the blues',
#  'his wife hadn`t held onto the debit card be',
#  'How is she spoilt? She`s like 10? 11? That was hard for her to be put up in front of 14m people.',
#  '.ughhhh!',
#  'I miss having an IT dept',
#  'What killed me was the 150 lb dummy that you can`t drag.',
#  'I accidentaly slammed my finger in the trunk',
#  '**** it!',
#  '****.',
#  'NOOOOO I hate traffic',
#  'I miss you too.',
#  'sorry',
#  'heartburn',
#  'bummed',
#  '.sorry',
#  'n depressing',
#  ', i think or very late 2009! its just wrong',
#  'miss',
#  'annoyed that everyone seems to tan apart from me! freckles and sunburn',
#  'I ordered some on the 8th and they still haven`t arrived. 3 weeks and still no books',
#  'can`t believe they`re divorcing',
#  'bad',
#  'My poor wife.',
#  'blacklisted by IT here..',
#  'e feeling  Its a little depressing',
#  '****',
#  'scratchy',
#  'n i wont be home to co host with you!',
#  'ughhhhhhhhhhhh  :/',
#  ', to think their wives are nuts.',
#  'doesn`t work',
#  'no fair.',
#  'Bad',
#  'Trying to recover photos after a problem between Windows and my XD card. Result: shots are all half visible  **** Microsoft...',
#  'Wish I could listen but because I`m from Canada, the website won`t let me!',
#  'e not interested',
#  'hate',
#  'sorry',
#  'not google friendly',
#  'Hates',
#  'feel like ****',
#  'I need a blackberry',
#  'annoying',
#  'scratchy',
#  'she is waiting very impatiently',
#  'but no luck  I think i`m sick.',
#  'damp',
#  'Failed on first day.  Twic',
#  'Oh, geez. I`m hungry.',
#  'I feel bad for you',
#  'it`s killing me.',
#  '.scary!',
#  'really sucks,',
#  'miss',
#  '**** shame',
#  'watched a small girl cry and it`s sad',
#  'Oh No!',
#  '.. I gave up on it',
#  'harrassment.',
#  'BADLY!!',
#  'Wow  That had to be difficult',
#  'i think that studying has really started taking its toll..',
#  'uncomfortable',
#  'Missing my baby ducks',
#  'hate',
#  'k hurts',
#  'I`m stayin til 630',
#  'doesn`t like us happy',
#  'migraine!',
#  'angry',
#  'miss',
#  'they`ll tame you!',
#  "my three most hated words are 'see you monday'",
#  'sad',
#  'I am in so much pain I really don`t feel too good. Couldn`t eat my dinner',
#  'People are cruel sometime',
#  'Sick',
#  'headache..',
#  'painful',
#  'That sucks about your prints. Sorry',
#  'Weather sucks!!...',
#  'work soonnnnnn  it`s looking rly dead today...',
#  'so upset',
#  'miss',
#  'I`m  going to miss seeing you like everyday',
#  'sick no',
#  'is kinda freaking me out ri',
#  'I miss you too,',
#  'It is a sad, lonely profession.',
#  'no fair.',
#  '**** distraaaaacting',
#  'that doesn`t sound too great',
#  'iPhone keypad sucks',
#  'Tummy hurts',
#  'Another Lake Park kid is going to Tulane. I`m not unique anymore',
#  ', sorry I cant be there tonight',
#  'Im not getting any treatments,',
#  'again your fault  i didnt make u leave',
#  'sorry',
#  'expensive!',
#  'I`m really disappointed; I had pretty high hopes for this one.',
#  'scared',
#  'upset..',
#  'i am being ignored! not a good day',
#  'That is annoying. What gear is it? I`ll take it off your hands',
#  'stupid ladder y did you have to collapse and make me fall on my back/bum???',
#  'I miss you R.....',
#  'they were all ugly',
#  'can`t sleep',
#  'problem',
#  'damage..',
#  'Ugh soooo much work to',
#  'fuuuuuuck  idk if andy can get youuuu',
#  'doesnt look good  we have to go burn some lampions',
#  'hurts.',
#  'bad',
#  'i had a dream that u didn`t like me',
#  'Ugh, still sick. This Calgary cold has lasted forever.',
#  '.I`m very ashamed.',
#  'o shabby',
#  'I have uncontrolable',
#  'sorry',
#  'harrassed me and tried to break in my house!!',
#  'Not feelin right.',
#  'I can`t seem to find it,',
#  'Bad times for everyone  Whywhywhy do we have to write essays  No fair',
#  'sick',
#  'im so jealous icant do',
#  'I just can`t stand',
#  'mad',
#  'rejected',
#  'I`ll miss my tweeps',
#  '! I can`t STAND that I cannot be there this summer!',
#  'today the sun is not here!',
#  'not as good',
#  'This weather is awful!',
#  'and_jay hi!  **** your job!',
#  'A isn`t cooperating',
#  '****',
#  'Learned a lesson the hard way.',
#  'sorry',
#  'Tough week for both of us and neither is really up for it. Plus our neighbor died',
#  'Cant believe Venus lost. A real shame. Smh. I think im getting sick  Had such a **** week, doesnt look like the wknd is gona be better!',
#  'I really missed this',
#  'Sorry about the weather, hopefully you`re not in the 2-3 hour wx delays here in BWI',
#  'Sorry, that was a bit negative!',
#  'unpleasant',
#  'tough',
#  'hurting',
#  'i don`t know what to do..',
#  'See? Sucked you right in.  The only problem will be church/Sunday race conflicts, but that`s why God gave us',
#  'I feel actual heartbreak..',
#  'But Jeff will have a hard time from 42nd',
#  'Absolutely I have been sick .. I want to go home',
#  'not good',
#  'Sorry',
#  'SUCKs',
#  'I don`t wanna go',
#  'jealous!',
#  'Basically doubled my time.',
#  'New picture isn`t working',
#  'hungry.',
#  'hate twitter',
#  'horrible.',
#  'I`m up. getting ready for skill. can`t wait to fail my bio final yay! ugh, honor classes suckkkk.  ):',
#  'sorry',
#  'I miss',
#  'saddens',
#  'Ugghhh',
#  'not so fun',
#  'hate',
#  'jealous*',
#  'hard',
#  'feel bad ov',
#  'weak',
#  'Sorry',
#  'wow, 5 pm rolled around really fast.',
#  'useless',
#  'Worst day ever.',
#  '****',
#  'tight this year',
#  '****',
#  'I`m soo jealous right now!!',
#  'Here comes the utter shite',
#  'missing my bffls! missing my friday night dates!',
#  '*Wabble Wabble*',
#  '. Not cool.',
#  'tired!',
#  'poo',
#  'I`m not feeling very inspired today..',
#  'i get less ideas every day, and every day',
#  'working sucks bi',
#  'Upset',
#  'that`s sad  what kind of mess are you getting into this weekend?',
#  'complicated?',
#  'bored!',
#  't sucks',
#  'fell on the sidewalk in harvard square.  stupid cobblestones!  now my hand hurts',
#  'either my inerne is **** or my mind is but i`m pretty sure that it`s the internet',
#  'sad th',
#  'd missed everythin',
#  'is sad',
#  'banging',
#  'envy',
#  'cats are gone.',
#  'I`m gonna miss him!!',
#  'sick',
#  'spoiled',
#  'Insomnia at its finest. Go to bed at 11:30, fully awake at 2. Grrr.',
#  'worst',
#  'sorry',
#  'don`t think that went well,',
#  'sidekick',
#  'sorry',
#  'man that sucks.',
#  'I`m really nervous ab',
#  'need to focus on kid`s packing but cant',
#  'that sucks mama',
#  'sadly.',
#  'hurts',
#  'sad',
#  'bugs',
#  'hate',
#  'My stomach effing hurts. Sadly there`ll be no gym class this afternoon',
#  'sadly ..',
#  '**** school!',
#  'dead',
#  'm crying',
#  'going bad',
#  'feeling like poo today',
#  'I wish I had company',
#  'My Power was cut off',
#  'boo',
#  'not happy!!! so',
#  'It was going to happen one day but I so feel for the girl AND her mum',
#  'Stupid idiot who ran a stop sing and almost killed me and my car!',
#  'y regretting',
#  'bored..',
#  'miss',
#  'nursing my scratches and bumps from Festivus mud wrestling. I swear there`s still dirt in my hair but a good time was had by all',
#  'missing',
#  'Cried',
#  'my head aches badly',
#  'connection errors a plenty.',
#  'sorry guys,',
#  'actually darn,',
#  'wtf happened?',
#  'worst',
#  'sorry',
#  'Sad',
#  '**** it',
#  'o bad',
#  'nervous',
#  'no one told me the mutual admiration society was meeting',
#  'my stomach actually hurts.',
#  'is feeling really sick',
#  'no window seat',
#  'I`m a lil sad',
#  'hasn`t recovered-n',
#  'want to charge way too much extra for it',
#  'bad',
#  'soooo jelous of you',
#  'sad th',
#  'stuck',
#  'I`ve run out of texts!',
#  'stressful',
#  '#itsucks',
#  'hard',
#  'Wishin I didn`t have to work',
#  'missing',
#  'Sick..',
#  't don`t understand',
#  'They cancel flights and don`t have a lot of backup planes. And no first class',
#  'saddest',
#  'hard to say goodbye',
#  'Stupid COMM class',
#  'miss',
#  'No luck for PC gamers',
#  'im so sick',
#  'a second chance shudnt have. mowgli didnt. gutted',
#  'I`m sick',
#  'cut myself',
#  'freaking out',
#  'spray tan = fail on legs and feet. I`ve been scrubbing them and feet look better, but they looked awful this morning  Everywhere else = ok',
#  'i`m pretty scared.',
#  'stopped',
#  'Apparently not.',
#  'missed',
#  'she`s probably worried  srry hun',
#  'that doesnt look very promising',
#  'so sad ab',
#  'oh no!  i`m sorry',
#  'couldn`t participate',
#  'but cant get home',
#  'kick me',
#  'sad',
#  'i haven`t really been happy',
#  'system is DEAD!!',
#  'fail',
#  'sad',
#  'miss',
#  'sunburnt',
#  'So jealous.',
#  'FRUSTRATING!!',
#  'bruised.',
#  'i got grounded',
#  'i see i gets the no love   whats up with that',
#  'miss',
#  'sad.',
#  'im sick.',
#  '? It is very sad',
#  't sucks',
#  'bored',
#  'shakalohana week two of flat wavez no surfin',
#  'bored',
#  'sadly',
#  'driving me nuts..',
#  'depressed',
#  'Twitter is slowing me down today.',
#  'sad',
#  'careless',
#  'aww',
#  'this is sounding like the worst lurgy ever - the one that just won`t go away ..  ...are you ready for end-of-rope action yet??',
#  'headache',
#  'i HATE it',
#  'bored',
#  'ugly',
#  'tired as hell!!!! be',
#  'which i offiacial suck at',
#  'Ugh!',
#  'bad choice',
#  'i m totally confused and bored..',
#  'problem.',
#  'miss',
#  'Fail.',
#  'Bored and lonely at work',
#  'afraid',
#  'miss',
#  '_Hall Is that why you aint answer my call? Thought we were homies!?',
#  'tired as ****.',
#  'nervous',
#  'hurt',
#  'She did well and only checked her phone 80 times',
#  'not doing relay  oh well.',
#  'Is it possible to a have phobia of phobias? Afraid to look at list.',
#  'dead bird',
#  'Poor',
#  't I can`t write fast enough',
#  'it`s so not TGIF for me!!',
#  'sry',
#  'Sadly not',
#  'loner',
#  'jealous',
#  'e never speaks to me',
#  'i`m so tired',
#  'i have sore throat. that`s suck.',
#  's miserable',
#  'miss you guys.',
#  'with my illness comes the joys of multiple mouth ulcers,',
#  'missed th',
#  'not a fan',
#  'worse',
#  'Iï¿½m so tired,had a bad day',
#  ': to triste',
#  'ScREW',
#  'Visiting family in hospital = not fun',
#  'i have no motivation',
#  'nauseas.',
#  'not so good mood..',
#  'lost',
#  'At work sick',
#  'I wanna go see the cab really bad.',
#  'Unfortunately,',
#  ', i have a really sore knee cant walk',
#  'missed',
#  'bored.',
#  'This song is a slap on you face!!  ? http://blip.fm/~5jib6',
#  'it doesnt match up',
#  'that sucks!',
#  'missing my hobo/*',
#  'pain',
#  'ly sa',
#  '_lord Can`t we just all get along?',
#  'far',
#  '. I don`t like the indentation',
#  'i would die if they played Pushit.',
#  'sad',
#  'it made me sad',
#  'AHHHH! Cant find anything because I have way too much open',
#  'booo..',
#  'My computer is being killed by a combo of mirrors edge and really poor win7 thermal management...75c gpu = one sad game',
#  'hate',
#  'It is driving me completely insane.',
#  'slammed',
#  'I`ve seriously had enough',
#  'feelin ill.',
#  'Gonna miss my gurl',
#  '****..',
#  'bored.',
#  'slower',
#  'And the 10 free minute button didn`t work.',
#  '.  he`s in bed sick. Heavy fever. Went to dr`s. Part of the reason i`m watching Aladdin 2 now and still haven`t been fed',
#  'HORRIBLE',
#  'im soooo loney',
#  'just sick of stupid guys',
#  'is saddened by Husker Access...no internet!',
#  '****!',
#  'Kinda pissed really wanted to',
#  'jealous-',
#  'sickkkkk.',
#  'giant wet stinky **** on me',
#  '**** up your nose!',
#  'is killing me',
#  'way to many chocolate animal crackers',
#  'don`t know  and no not at all',
#  'sooo sad,',
#  'sick',
#  'sick',
#  'heartbroken',
#  'If only I had a job...',
#  'o sorry!',
#  '&its breakin my heart;',
#  'I think the x3 is confusing',
#  'I`m so unhappy being here. I hate it.',
#  'kaput.',
#  'seriously im sooooo tired dont know if i`ll survive the 8 hour shift',
#  'I wish I didn`t feel like ****.',
#  'sad',
#  'my stomach hurts',
#  'how come you cant stay',
#  ...]

# %%
# TDM for positive sentiments
vec_n = CountVectorizer()
X_n = vec_n.fit_transform(negative_docs)
tdm_n = pd.DataFrame(X_n.toarray(), columns=vec_n.get_feature_names())

# In this case for negative sentiment tweets, "uh" appeared 6 times, "sigh" appeared 7 times, "dangerously" appeared 4 times.
sliced = tdm_n.loc[:10,["uh","sigh","dangerously"]]
sliced
# Out:
#     uh  sigh  dangerously
# 0    0     0            0
# 1    0     0            0
# 2    0     0            0
# 3    0     0            0
# 4    0     0            1
# 5    0     0            0
# 6    1     0            0
# 7    0     1            0
# 8    0     0            0
# 9    0     0            0
# 10   0     0            0

# %%
# Let us do the above two cells for neutral and positive sentiments as well
neutral_docs = [row['selected_text'] for index,row in df.iterrows() if row['sentiment'] == 'neutral']
vec_t = CountVectorizer()
X_t = vec_t.fit_transform(neutral_docs)
tdm_t = pd.DataFrame(X_t.toarray(), columns=vec_t.get_feature_names())

positive_docs = [row['selected_text'] for index,row in df.iterrows() if row['sentiment'] == 'positive']
vec_p = CountVectorizer()
X_p = vec_p.fit_transform(positive_docs)
tdm_p = pd.DataFrame(X_p.toarray(), columns=vec_p.get_feature_names())

# %% [markdown]
# ## Probability of words in each sentiment class (Part 1)
# - We now need to find the total number of times each word appeared in each sentiment class. For example, as seen above, "uh" appeared 6 times in the negative sentiment class.
# - After that, we will use the frequency values to find the proability that each word appears in each sentiment class.

# %%
# Frequency of words in negative sentiment class
word_list_n = vec_n.get_feature_names();    
count_list_n = X_n.toarray().sum(axis=0) 
freq_n = dict(zip(word_list_n,count_list_n))
freq_n
# Out:
# {'00': 2,
#  '09': 1,
#  '0ut': 1,
#  '10': 5,
#  '100': 2,
#  '10000000000': 1,
#  '107': 1,
#  '11': 3,
#  '12': 2,
#  '12th': 1,
#  '13': 1,
#  '13pdrmj': 1,
#  '14': 1,
#  '140': 1,
#  '14m': 1,
#  '15': 1,
#  '150': 1,
#  '15am': 1,
#  '16th': 1,
#  '18hrs': 1,
#  '1st': 2,
#  '20': 2,
#  '200': 1,
#  '2008': 1,
#  '2009': 1,
#  '21': 2,
#  '22hrs': 1,
#  '24hrs': 1,
#  '27': 1,
#  '2day': 2,
#  '2nd': 1,
#  '2nit': 1,
#  '2stop': 1,
#  '30': 5,
#  '30am': 1,
#  '333333333': 1,
#  '35': 1,
#  '36': 1,
#  '3647': 1,
#  '38': 1,
#  '3am': 1,
#  '3wordsaftersex': 1,
#  '42nd': 1,
#  '45': 1,
#  '4th': 1,
#  '51': 1,
#  '58': 1,
#  '5ghz': 1,
#  '5hours': 1,
#  '5jib6': 1,
#  '630': 1,
#  '674p1': 1,
#  '6th': 2,
#  '7500': 1,
#  '75c': 1,
#  '7th': 1,
#  '80': 1,
#  '800': 1,
#  '87': 1,
#  '88': 1,
#  '8th': 1,
#  '90': 1,
#  '970': 1,
#  '9am': 1,
#  '9pm': 1,
#  '_c': 1,
#  '_da_': 1,
#  '_hall': 1,
#  '_kill_boy': 1,
#  '_l': 2,
#  '_lord': 1,
#  '_mcloven': 1,
#  '_skies': 1,
#  '_troy': 1,
#  '_violence': 1,
#  '_x': 1,
#  'aaaaaaaaaahhhhhhhh': 1,
#  'aaaaarrrrggghhh': 1,
#  'aaaagggessss': 1,
#  'aaaaw': 1,
#  'aaarrrgggghhh': 1,
#  'aaawww': 1,
#  'aah': 1,
#  'aam': 1,
#  'aarrgghh': 1,
#  'ab': 7,
#  'abandoned': 1,
#  'abiding': 1,
#  'able': 5,
#  'about': 59,
#  'absolutely': 6,
#  'absolutley': 1,
#  'abt': 3,
#  'abuse': 1,
#  'abusive': 1,
#  'ac': 2,
#  'accadentally': 1,
#  'accept': 1,
#  'access': 3,
#  'accident': 7,
#  'accidentally': 3,
#  'accidentaly': 1,
#  'accidents': 1,
#  'accompany': 1,
#  'accomplish': 1,
#  'account': 3,
#  'ace': 1,
#  'ach': 2,
#  'ache': 10,
#  'aches': 3,
#  'aching': 1,
#  'acid': 2,
#  'ack': 1,
#  'act': 3,
#  'acting': 2,
#  'action': 2,
#  'activities': 1,
#  'activity': 1,
#  'actual': 2,
#  'actually': 7,
#  'acute': 1,
#  'addicted': 2,
#  'addicting': 1,
#  'address': 2,
#  'addresses': 1,
#  'adjustment': 1,
#  'admiration': 1,
#  'advance': 1,
#  'advil': 1,
#  'af': 2,
#  'affected': 1,
#  'affects': 1,
#  'afford': 7,
#  'afraid': 20,
#  'after': 13,
#  'afterjune': 1,
#  'afternoon': 1,
#  'agaaaaaaiiiin': 1,
#  'again': 38,
#  'against': 4,
#  'ages': 3,
#  'aggressive': 1,
#  'agh': 2,
#  'agitated': 1,
#  'ago': 2,
#  'agree': 1,
#  'agreed': 1,
#  'agressive': 1,
#  'ah': 6,
#  'aha': 2,
#  'ahahaha': 1,
#  'ahead': 4,
#  'ahh': 5,
#  'ahhh': 5,
#  'ahhhh': 3,
#  'ahhhhhhh': 1,
#  'ahhhhhhhh': 1,
#  'aholes': 1,
#  'aidan': 1,
#  'aila': 1,
#  'aim': 1,
#  'ain': 3,
#  'aint': 6,
#  'air': 2,
#  'aircon': 1,
#  'airport': 1,
#  'airsoft': 1,
#  'airy': 1,
#  'aka': 1,
#  'al': 3,
#  'aladdin': 1,
#  'alarm': 2,
#  'alas': 4,
#  'alaska': 1,
#  'album': 1,
#  'alcohol': 2,
#  'alex': 1,
#  'all': 111,
#  'allergic': 4,
#  'allergies': 4,
#  'allergy': 1,
#  'alley': 1,
#  'allllllllll': 1,
#  'allowed': 2,
#  'almost': 13,
#  'alone': 15,
#  'along': 2,
#  'alot': 6,
#  'alreadi': 1,
#  'alreadt': 1,
#  'already': 28,
#  'alright': 1,
#  'also': 10,
#  'alter': 1,
#  'alto': 1,
#  'always': 18,
#  'am': 95,
#  'amazing': 1,
#  'amazon': 1,
#  'ambulance': 1,
#  'american': 1,
#  'americans': 1,
#  'amp': 1,
#  'amusing': 1,
#  'an': 43,
#  'and': 258,
#  'and_jay': 1,
#  'android': 1,
#  'andy': 1,
#  'anerexic': 1,
#  'ange': 1,
#  'angela': 1,
#  'angrily': 1,
#  'angrrry': 1,
#  'angry': 9,
#  'animal': 2,
#  'ankle': 1,
#  'announced': 1,
#  'annoyed': 11,
#  'annoying': 20,
#  'annoyingly': 1,
#  'anoher': 1,
#  'another': 12,
#  'answer': 8,
#  'answerer': 1,
#  'answers': 1,
#  'anthony': 1,
#  'antibiotics': 1,
#  'anticipating': 1,
#  'anxiety': 4,
#  'anxious': 3,
#  'any': 25,
#  'anymore': 30,
#  'anyone': 6,
#  'anything': 13,
#  'anytime': 2,
#  'anyway': 3,
#  'anyways': 3,
#  'anywayz': 1,
#  'anywhere': 3,
#  'ao': 1,
#  'apart': 6,
#  'apartment': 1,
#  'apathetic': 2,
#  'apathy': 1,
#  'apologies': 5,
#  'apologised': 1,
#  'apparently': 3,
#  'appartment': 1,
#  'appetite': 1,
#  'appetizing': 1,
#  'apple': 1,
#  'appreciating': 1,
#  'appreciation': 1,
#  'arabs': 1,
#  'ard': 2,
#  'are': 84,
#  'area': 1,
#  'aren': 8,
#  'arent': 2,
#  'arg': 2,
#  'arggghhhhhhhhhhh': 1,
#  'argghhh': 1,
#  'argh': 6,
#  'arghhhh': 1,
#  'argue': 1,
#  'arguing': 1,
#  'arm': 2,
#  'arms': 6,
#  'arnie': 1,
#  'arnold': 1,
#  'around': 7,
#  'arrest': 2,
#  'arrgghhhggguuuiiissshhhh': 1,
#  'arrival': 2,
#  'arrived': 2,
#  'arriving': 1,
#  'arseholes': 1,
#  'arthritus': 1,
#  'article': 1,
#  'artist': 1,
#  'as': 50,
#  'ashamed': 3,
#  'ashminov': 1,
#  'asia': 1,
#  'ask': 3,
#  'askin': 1,
#  'asking': 1,
#  'asleep': 5,
#  'asprin': 1,
#  'assembly': 1,
#  'asses': 1,
#  'assfuck': 1,
#  'assholes': 2,
#  'assignment': 1,
#  'assignments': 1,
#  'assumption': 1,
#  'asthma': 4,
#  'asylum': 1,
#  'at': 129,
#  'ate': 3,
#  'attack': 2,
#  'attacked': 2,
#  'attacking': 2,
#  'attempt': 1,
#  'attempts': 1,
#  'attend': 1,
#  'attention': 1,
#  'auntie': 1,
#  'aunts': 1,
#  'aussie': 1,
#  'automatically': 2,
#  'available': 3,
#  'availble': 1,
#  'avalina': 1,
#  'average': 2,
#  'averages': 1,
#  'avoid': 2,
#  'aw': 4,
#  'awake': 6,
#  'away': 25,
#  'awayyy': 1,
#  'awe': 4,
#  'aweful': 1,
#  'awesome': 2,
#  'awful': 18,
#  'awfully': 2,
#  'awkward': 1,
#  'awkwardly': 1,
#  'aww': 15,
#  'awww': 11,
#  'awwww': 2,
#  'awwwww': 2,
#  'awwwwwwww': 1,
#  'ay': 1,
#  'az': 1,
#  'b4': 2,
#  'ba': 5,
#  'baaaaaaaaaaackkkkkkkk': 1,
#  'baadly': 1,
#  'babe': 1,
#  'babies': 2,
#  'baby': 10,
#  'bac': 1,
#  'back': 44,
#  'backache': 1,
#  'backup': 1,
#  'bad': 247,
#  'baddd': 2,
#  'badluck': 1,
#  'badly': 12,
#  'badmicrosoft': 1,
#  'badu': 1,
#  'baffles': 1,
#  'bah': 6,
#  'bahhhh': 1,
#  'bak': 1,
#  'bake': 2,
#  'baked': 1,
#  'baking': 1,
#  'balcony': 1,
#  'baldness': 1,
#  'ball': 3,
#  'balling': 1,
#  'balls': 2,
#  'bang': 1,
#  'banged': 1,
#  'banging': 1,
#  'bangs': 1,
#  'bank': 2,
#  'banking': 1,
#  'bankruptcy': 1,
#  'banned': 2,
#  'bannished': 1,
#  'bar': 1,
#  'barca': 1,
#  'bare': 1,
#  'barely': 4,
#  'barked': 1,
#  'barks': 1,
#  'baseball': 2,
#  'based': 1,
#  'basement': 1,
#  'basic': 1,
#  'basically': 4,
#  'bastard': 1,
#  'bastards': 1,
#  'bat': 1,
#  'baterrry': 1,
#  'bath': 1,
#  'bathroom': 1,
#  'battery': 2,
#  'bb': 1,
#  'bby': 2,
#  'bc': 1,
#  'bccg': 1,
#  'bday': 1,
#  'be': 144,
#  'beach': 2,
#  'beans': 1,
#  'beast': 1,
#  'beasted': 1,
#  'beat': 5,
#  'beating': 1,
#  'beautiful': 1,
#  'bebe': 2,
#  'becase': 1,
#  'because': 22,
#  'beck': 1,
#  'become': 3,
#  'becomes': 1,
#  'becoming': 2,
#  'bed': 25,
#  'bee': 1,
#  'been': 41,
#  'beer': 3,
#  'bees': 1,
#  'before': 10,
#  'beginning': 1,
#  'beginnings': 1,
#  'behind': 4,
#  'bein': 2,
#  'being': 46,
#  'belated': 1,
#  'believe': 23,
#  'believed': 1,
#  'believers': 1,
#  'belive': 1,
#  'belly': 1,
#  'below': 1,
#  'belt': 1,
#  'benn': 1,
#  'besides': 1,
#  'best': 12,
#  'bestie': 1,
#  'bet': 3,
#  'better': 12,
#  'between': 3,
#  'beware': 1,
#  'beyonce': 1,
#  'beyond': 2,
#  'bf': 1,
#  'bffls': 1,
#  'bg': 1,
#  'bgt': 3,
#  'bi': 2,
#  'big': 14,
#  'bigger': 2,
#  'biggest': 1,
#  'bigoted': 1,
#  'bike': 3,
#  'biker': 1,
#  'bills': 2,
#  'bin': 1,
#  'bio': 2,
#  'biology': 1,
#  'bipolar': 1,
#  'bird': 4,
#  'birfdayy': 1,
#  'birthday': 6,
#  'bit': 28,
#  'bitch': 1,
#  'bite': 1,
#  'biting': 1,
#  'bits': 1,
#  'bittersweet': 1,
#  'biz': 1,
#  'bk': 1,
#  'bl': 1,
#  'blaaaqhhh': 1,
#  'black': 1,
#  'blackberry': 3,
#  'blacklisted': 1,
#  'blah': 7,
#  'blahh': 1,
#  'blame': 4,
#  'blamed': 1,
#  'blank': 1,
#  'blanket': 1,
#  'blatently': 1,
#  'bleed': 2,
#  'bleeding': 1,
#  'bleeds': 1,
#  'bleh': 2,
#  'bless': 1,
#  'blew': 1,
#  'blimey': 1,
#  'blind': 2,
#  'blinded': 1,
#  'blip': 3,
#  'bliss': 1,
#  'blister': 1,
#  'blistered': 1,
#  'bloated': 1,
#  'block': 2,
#  'blocked': 6,
#  'blocking': 1,
#  'blog': 5,
#  'blood': 2,
#  'bloody': 8,
#  'blown': 2,
#  'blows': 1,
#  'bludge': 1,
#  'blue': 3,
#  'blues': 2,
#  'bluff': 1,
#  'blunt': 1,
#  'blurryness': 1,
#  'boak': 1,
#  'board': 2,
#  'boat': 1,
#  'boc': 1,
#  'body': 2,
#  'boiling': 1,
#  'bolts': 1,
#  'bomb': 2,
#  'bone': 1,
#  'bones': 2,
#  'boo': 23,
#  'boo0o0o0o00oring': 1,
#  'booboo': 1,
#  'boohoohoo': 1,
#  'book': 1,
#  'booked': 2,
#  'books': 3,
#  'booo': 2,
#  'boooo': 1,
#  'boooooo': 1,
#  'boooooooo': 1,
#  'boooooooored': 1,
#  'booooored': 1,
#  'booored': 1,
#  'boot': 1,
#  'booted': 1,
#  'borde': 1,
#  'bordom': 1,
#  'bore': 2,
#  'bored': 118,
#  'boredd': 1,
#  'boredddd': 1,
#  'boreddddd': 1,
#  'boredom': 3,
#  'boreedd': 1,
#  'bores': 1,
#  'borin': 2,
#  'boring': 48,
#  'boringgg': 1,
#  'borred': 1,
#  'borriing': 1,
#  'boss': 3,
#  'boston': 1,
#  'both': 4,
#  'bother': 3,
#  'bothered': 1,
#  'bothering': 2,
#  'bots': 1,
#  'bottom': 2,
#  'bought': 2,
#  'bouncing': 1,
#  'bourdon': 1,
#  'bout': 6,
#  'boverd': 1,
#  'bowl': 1,
#  'bowling': 1,
#  'box': 3,
#  'boxes': 1,
#  'boy': 5,
#  'boys': 2,
#  'br': 1,
#  'brain': 5,
#  'branch': 1,
#  'brazillians': 1,
#  'bread': 1,
#  'break': 12,
#  'breaker': 1,
#  'breakfast': 1,
#  'breakin': 1,
#  'breaking': 4,
#  'breakingg': 1,
#  'breaks': 3,
#  'breast': 1,
#  'breathe': 3,
#  'brekkie': 1,
#  'brian': 2,
#  'bricked': 1,
#  'bridge': 1,
#  'brighi': 1,
#  'bring': 2,
#  'britains': 1,
#  'brittany': 1,
#  'bro': 3,
#  'broad': 1,
#  'brody': 1,
#  'broke': 31,
#  'broken': 26,
#  'brokt': 1,
#  'bronchitis': 1,
#  'brooke': 1,
#  'brooklyn': 1,
#  'brother': 1,
#  'brothers': 1,
#  'brought': 1,
#  'brrrrrr': 1,
#  'bruise': 2,
#  'bruised': 3,
#  'brummie': 1,
#  'brunch': 1,
#  'brunt': 1,
#  'brutal': 1,
#  'bt': 2,
#  'btw': 1,
#  'bu': 2,
#  'bud': 1,
#  'budget': 2,
#  'bug': 1,
#  'bugg': 1,
#  'bugger': 4,
#  'buggered': 1,
#  'buggin': 1,
#  'bugs': 2,
#  'build': 1,
#  'building': 1,
#  'buisnesses': 1,
#  'bulky': 1,
#  'bullied': 2,
#  'bullying': 1,
#  'bum': 3,
#  'bummed': 15,
#  'bummer': 15,
#  'bumped': 1,
#  'bumps': 1,
#  'bunny': 2,
#  'burden': 1,
#  'burger': 1,
#  'buried': 1,
#  'burn': 5,
#  'burned': 11,
#  'burnin': 1,
#  'burning': 2,
#  'burns': 1,
#  'burnt': 15,
#  'burrito': 1,
#  'burton': 1,
#  'bury': 1,
#  'bus': 9,
#  'business': 1,
#  'businesses': 1,
#  'bust': 2,
#  'busted': 3,
#  'busy': 12,
#  'but': 129,
#  'butt': 2,
#  'butter': 1,
#  'butterflies': 1,
#  'butterfly': 1,
#  'buttfuck': 1,
#  'button': 2,
#  'buy': 7,
#  'buzz': 2,
#  'buzzed': 3,
#  'bwi': 1,
#  'by': 19,
#  'bye': 7,
#  'cab': 1,
#  'cable': 2,
#  'calculator': 1,
#  'calculus': 1,
#  'calcutta': 1,
#  'calgary': 1,
#  'california': 3,
#  'call': 15,
#  'called': 2,
#  'callers': 1,
#  'callin': 1,
#  'calling': 2,
#  'calls': 1,
#  'came': 5,
#  'camera': 4,
#  'camping': 1,
#  'can': 179,
#  'canada': 1,
#  'cancel': 3,
#  'canceled': 3,
#  'cancelled': 9,
#  'cancelling': 1,
#  'cancer': 2,
#  'candid': 1,
#  'cannot': 14,
#  'cant': 56,
#  'cantt': 1,
#  'cantttt': 1,
#  'canucks': 1,
#  'canï': 1,
#  'cap': 1,
#  'capacity': 1,
#  'capitan': 1,
#  'car': 24,
#  'carbon': 1,
#  'card': 5,
#  'cardboard': 1,
#  'cardigan': 1,
#  'cards': 1,
#  'care': 10,
#  'career': 1,
#  'carefully': 1,
#  'careless': 3,
#  'cares': 2,
#  'carnt': 1,
#  'carol': 1,
#  'carrie': 2,
#  'case': 2,
#  'cash': 3,
#  'cassadee': 1,
#  'cat': 5,
#  'catch': 1,
#  'catche': 1,
#  'category': 1,
#  'cats': 4,
#  'caught': 4,
#  'cause': 7,
#  'cauzinhoooo': 1,
#  'cavity': 1,
#  'cd': 1,
#  'cecilia': 1,
#  'celebs': 1,
#  'cell': 1,
#  'cert': 1,
#  'ch': 2,
#  'chai': 1,
#  'chalky': 1,
#  'challanges': 1,
#  'challenge': 1,
#  'challenged': 1,
#  'chance': 8,
#  'chances': 1,
#  'change': 1,
#  'changed': 2,
#  'channel': 1,
#  'chaos': 1,
#  'charge': 2,
#  'charged': 1,
#  'charger': 1,
#  'charlene': 1,
#  'charley': 1,
#  'chars': 1,
#  'charter': 1,
#  'chased': 1,
#  'chat': 3,
#  'chatting': 1,
#  'cheap': 2,
#  'cheaper': 2,
#  'cheat': 1,
#  'cheated': 1,
#  'checked': 3,
#  'checking': 1,
#  'cheddar': 1,
#  'cheek': 1,
#  'cheer': 1,
#  'cheering': 1,
#  'cheers': 1,
#  'cheese': 2,
#  'cheesecake': 1,
#  'cheesy': 1,
#  'chem': 2,
#  'chemistry': 1,
#  'chest': 2,
#  'chick': 2,
#  'chickened': 1,
#  'children': 4,
#  'chili': 1,
#  'chill': 1,
#  'chilly': 2,
#  'chin': 1,
#  'chinese': 1,
#  'chipotle': 1,
#  'chips': 2,
#  'chocked': 1,
#  'chocolate': 5,
#  'choice': 3,
#  'choked': 1,
#  'cholesterol': 1,
#  'chomp': 2,
#  'choose': 1,
#  'chop': 1,
#  'chose': 1,
#  'chow': 1,
#  'chris': 1,
#  'christ': 2,
#  'christian': 2,
#  'chucking': 2,
#  'church': 1,
#  'ciber': 1,
#  'cici': 1,
#  'cider': 1,
#  'cinema': 1,
#  'cinemas': 1,
#  'circuit': 1,
#  'citipointe': 1,
#  'citizens': 1,
#  'ck': 1,
#  'cl': 2,
#  'cla': 1,
#  'clark': 1,
#  'class': 13,
#  'classes': 4,
#  'clean': 1,
#  'cleanin': 1,
#  'cleaning': 1,
#  'clear': 1,
#  'clearly': 1,
#  'clever': 1,
#  'clingy': 1,
#  'clock': 2,
#  'clocked': 1,
#  'clogged': 1,
#  'clorox': 1,
#  'close': 3,
#  'closed': 2,
#  'closes': 1,
#  'closing': 1,
#  'clot': 1,
#  'clothes': 1,
#  'cloudy': 1,
#  'clown': 1,
#  'clowns': 1,
#  'clue': 1,
#  'clumsy': 1,
#  'clutter': 1,
#  'cnt': 3,
#  'co': 3,
#  'coast': 1,
#  'cobblestones': 1,
#  'cod': 1,
#  'code': 2,
#  'coding': 1,
#  'coffee': 8,
#  'coffeeclub': 1,
#  'cold': 28,
#  'colds': 1,
#  'collapse': 1,
#  'collapses': 2,
#  'collection': 2,
#  'college': 2,
#  'com': 4,
#  'combined': 1,
#  'combo': 1,
#  'come': 22,
#  'comes': 3,
#  'comfortable': 3,
#  'coming': 5,
#  'comm': 1,
#  'commands': 1,
#  'comment': 1,
#  'comments': 1,
#  'company': 2,
#  'competetion': 1,
#  'competition': 1,
#  'complain': 2,
#  'complaining': 2,
#  'complete': 2,
#  'completely': 8,
#  'complex': 1,
#  'complicated': 5,
#  'compose': 1,
#  'comps': 1,
#  'computer': 9,
#  'conan': 1,
#  'concentrate': 2,
#  'concept': 1,
#  'concert': 2,
#  'condolence': 1,
#  'confident': 1,
#  'confirmed': 1,
#  'conflicts': 1,
#  'confsuing': 1,
#  'confuse': 1,
#  'confused': 7,
#  'confusin': 1,
#  'confusing': 3,
#  'confusions': 1,
#  'conjunctivitis': 1,
#  'connection': 2,
#  'considerably': 1,
#  'considering': 1,
#  'constant': 1,
#  'constantly': 1,
#  'contest': 1,
#  'continually': 1,
#  'controls': 1,
#  'convenient': 1,
#  'conversation': 2,
#  'convinced': 3,
#  'cook': 1,
#  'cool': 10,
#  'cooperating': 2,
#  'cope': 2,
#  'copies': 1,
#  'cops': 1,
#  'copy': 1,
#  'core': 4,
#  'corner': 1,
#  'corpes': 1,
#  'corrupted': 1,
#  'cos': 4,
#  'cost': 3,
#  'costa': 1,
#  'costco': 1,
#  'costly': 2,
#  'costs': 2,
#  'cough': 3,
#  'coughing': 1,
#  'could': 21,
#  'couldn': 15,
#  'couldnt': 4,
#  'count': 1,
#  'counting': 2,
#  'county': 1,
#  'court': 1,
#  'cousin': 1,
#  'cousins': 1,
#  'cover': 2,
#  'covered': 1,
#  'cow': 1,
#  'cowering': 1,
#  'coworkers': 1,
#  'crack': 2,
#  'cracked': 1,
#  'crackers': 1,
#  'craigslist': 1,
#  'crampin': 1,
#  'cramping': 1,
#  'cramples': 1,
#  'cramps': 4,
#  'crampsss': 1,
#  'cranking': 1,
#  'crappy': 12,
#  'crash': 3,
#  'crashed': 5,
#  'crashing': 2,
#  'craving': 1,
#  'crawl': 2,
#  'crawling': 1,
#  'craziness': 1,
#  'crazy': 19,
#  'cream': 3,
#  'creased': 1,
#  'created': 2,
#  'creativity': 1,
#  'credit': 1,
#  'credo': 1,
#  'creek': 1,
#  'creep': 1,
#  'creeper': 2,
#  'creepy': 2,
#  'cried': 9,
#  'cries': 4,
#  'crime': 1,
#  'criminal': 1,
#  'cringe': 1,
#  'crisps': 1,
#  'critical': 1,
#  'crooning': 1,
#  'cross': 2,
#  'crossing': 1,
#  'crowds': 1,
#  'cruel': 3,
#  'cruise': 1,
#  'crushed': 3,
#  'cry': 39,
#  'cryed': 1,
#  'cryin': 2,
#  'crying': 24,
#  'cryy': 2,
#  'cubs': 1,
#  'cud': 1,
#  'cuddle': 2,
#  'current': 1,
#  'currently': 1,
#  'curse': 3,
#  'cursed': 1,
#  'cursing': 1,
#  'cut': 7,
#  'cute': 3,
#  'cuties': 1,
#  'cutting': 1,
#  'cuz': 9,
#  'cyberstalking': 1,
#  'cycle': 1,
#  'cyclone': 1,
#  'da': 1,
#  'daaaaang': 1,
#  'daaaang': 1,
#  'daaammmnnnnn': 1,
#  'dad': 3,
#  'dada': 1,
#  'daddy': 4,
#  'dam': 2,
#  'damage': 3,
#  'damit': 1,
#  'damm': 1,
#  ...}

# %%
# Frequency of words in neutral sentiment class
word_list_t = vec_t.get_feature_names();    
count_list_t = X_t.toarray().sum(axis=0) 
freq_t = dict(zip(word_list_t,count_list_t))

# Frequency of words in positive sentiment class
word_list_p = vec_p.get_feature_names();    
count_list_p = X_p.toarray().sum(axis=0) 
freq_p = dict(zip(word_list_p,count_list_p))

# %%
# Probabilities of words in negative sentiment class
prob_n = []
total_n_values = sum(freq_n.values())
for word, count in zip(word_list_n, count_list_n):
    prob_n.append(count / total_n_values)
n_prob_dict = dict(zip(word_list_n, prob_n))
n_prob_dict
# Out:
# {'00': 7.218392463998267e-05,
#  '09': 3.6091962319991336e-05,
#  '0ut': 3.6091962319991336e-05,
#  '10': 0.0001804598115999567,
#  '100': 7.218392463998267e-05,
#  '10000000000': 3.6091962319991336e-05,
#  '107': 3.6091962319991336e-05,
#  '11': 0.00010827588695997402,
#  '12': 7.218392463998267e-05,
#  '12th': 3.6091962319991336e-05,
#  '13': 3.6091962319991336e-05,
#  '13pdrmj': 3.6091962319991336e-05,
#  '14': 3.6091962319991336e-05,
#  '140': 3.6091962319991336e-05,
#  '14m': 3.6091962319991336e-05,
#  '15': 3.6091962319991336e-05,
#  '150': 3.6091962319991336e-05,
#  '15am': 3.6091962319991336e-05,
#  '16th': 3.6091962319991336e-05,
#  '18hrs': 3.6091962319991336e-05,
#  '1st': 7.218392463998267e-05,
#  '20': 7.218392463998267e-05,
#  '200': 3.6091962319991336e-05,
#  '2008': 3.6091962319991336e-05,
#  '2009': 3.6091962319991336e-05,
#  '21': 7.218392463998267e-05,
#  '22hrs': 3.6091962319991336e-05,
#  '24hrs': 3.6091962319991336e-05,
#  '27': 3.6091962319991336e-05,
#  '2day': 7.218392463998267e-05,
#  '2nd': 3.6091962319991336e-05,
#  '2nit': 3.6091962319991336e-05,
#  '2stop': 3.6091962319991336e-05,
#  '30': 0.0001804598115999567,
#  '30am': 3.6091962319991336e-05,
#  '333333333': 3.6091962319991336e-05,
#  '35': 3.6091962319991336e-05,
#  '36': 3.6091962319991336e-05,
#  '3647': 3.6091962319991336e-05,
#  '38': 3.6091962319991336e-05,
#  '3am': 3.6091962319991336e-05,
#  'activity': 3.6091962319991336e-05,
#  'actual': 7.218392463998267e-05,
#  'actually': 0.0002526437362399394,
#  'acute': 3.6091962319991336e-05,
#  'addicted': 7.218392463998267e-05,
#  'addicting': 3.6091962319991336e-05,
#  'address': 7.218392463998267e-05,
#  'addresses': 3.6091962319991336e-05,
#  'adjustment': 3.6091962319991336e-05,
#  'admiration': 3.6091962319991336e-05,
#  'advance': 3.6091962319991336e-05,
#  'advil': 3.6091962319991336e-05,
#  'af': 7.218392463998267e-05,
#  'affected': 3.6091962319991336e-05,
#  'affects': 3.6091962319991336e-05,
#  'afford': 0.0002526437362399394,
#  'afraid': 0.0007218392463998268,
#  'after': 0.00046919551015988737,
#  'afterjune': 3.6091962319991336e-05,
#  'afternoon': 3.6091962319991336e-05,
#  'agaaaaaaiiiin': 3.6091962319991336e-05,
#  'again': 0.0013714945681596708,
#  'against': 0.00014436784927996535,
#  'ages': 0.00010827588695997402,
#  'aggressive': 3.6091962319991336e-05,
#  'agh': 7.218392463998267e-05,
#  'agitated': 3.6091962319991336e-05,
#  'ago': 7.218392463998267e-05,
#  'agree': 3.6091962319991336e-05,
#  'agreed': 3.6091962319991336e-05,
#  'agressive': 3.6091962319991336e-05,
#  'ah': 0.00021655177391994803,
#  'aha': 7.218392463998267e-05,
#  'ahahaha': 3.6091962319991336e-05,
#  'ahead': 0.00014436784927996535,
#  'ahh': 0.0001804598115999567,
#  'ahhh': 0.0001804598115999567,
#  'ahhhh': 0.00010827588695997402,
#  'ahhhhhhh': 3.6091962319991336e-05,
#  'ahhhhhhhh': 3.6091962319991336e-05,
#  'aholes': 3.6091962319991336e-05,
#  'aidan': 3.6091962319991336e-05,
#  'aila': 3.6091962319991336e-05,
#  'aim': 3.6091962319991336e-05,
#  'ain': 0.00010827588695997402,
#  'aint': 0.00021655177391994803,
#  'air': 7.218392463998267e-05,
#  'aircon': 3.6091962319991336e-05,
#  'airport': 3.6091962319991336e-05,
#  'airsoft': 3.6091962319991336e-05,
#  'airy': 3.6091962319991336e-05,
#  'aka': 3.6091962319991336e-05,
#  'al': 0.00010827588695997402,
#  'aladdin': 3.6091962319991336e-05,
#  'alarm': 7.218392463998267e-05,
#  'alas': 0.00014436784927996535,
#  'alaska': 3.6091962319991336e-05,
#  'album': 3.6091962319991336e-05,
#  'alcohol': 7.218392463998267e-05,
#  'alex': 3.6091962319991336e-05,
#  'all': 0.004006207817519039,
#  'allergic': 0.00014436784927996535,
#  'allergies': 0.00014436784927996535,
#  'allergy': 3.6091962319991336e-05,
#  'alley': 3.6091962319991336e-05,
#  'allllllllll': 3.6091962319991336e-05,
#  'allowed': 7.218392463998267e-05,
#  'almost': 0.00046919551015988737,
#  'alone': 0.0005413794347998701,
#  'along': 7.218392463998267e-05,
#  'alot': 0.00021655177391994803,
#  'alreadi': 3.6091962319991336e-05,
#  'alreadt': 3.6091962319991336e-05,
#  'already': 0.0010105749449597576,
#  'alright': 3.6091962319991336e-05,
#  'also': 0.0003609196231999134,
#  'alter': 3.6091962319991336e-05,
#  'alto': 3.6091962319991336e-05,
#  'bye': 0.0002526437362399394,
#  'cab': 3.6091962319991336e-05,
#  'cable': 7.218392463998267e-05,
#  'calculator': 3.6091962319991336e-05,
#  'calculus': 3.6091962319991336e-05,
#  'calcutta': 3.6091962319991336e-05,
#  'calgary': 3.6091962319991336e-05,
#  'california': 0.00010827588695997402,
#  'call': 0.0005413794347998701,
#  'called': 7.218392463998267e-05,
#  'callers': 3.6091962319991336e-05,
#  'callin': 3.6091962319991336e-05,
#  'calling': 7.218392463998267e-05,
#  'calls': 3.6091962319991336e-05,
#  'came': 0.0001804598115999567,
#  'camera': 0.00014436784927996535,
#  'camping': 3.6091962319991336e-05,
#  'can': 0.006460461255278449,
#  'canada': 3.6091962319991336e-05,
#  'cancel': 0.00010827588695997402,
#  'canceled': 0.00010827588695997402,
#  'cancelled': 0.00032482766087992205,
#  'cancelling': 3.6091962319991336e-05,
#  'cancer': 7.218392463998267e-05,
#  'candid': 3.6091962319991336e-05,
#  'cannot': 0.0005052874724798788,
#  'cant': 0.002021149889919515,
#  'cantt': 3.6091962319991336e-05,
#  'cantttt': 3.6091962319991336e-05,
#  'canucks': 3.6091962319991336e-05,
#  'canï': 3.6091962319991336e-05,
#  'cap': 3.6091962319991336e-05,
#  'capacity': 3.6091962319991336e-05,
#  'capitan': 3.6091962319991336e-05,
#  'car': 0.0008662070956797921,
#  'carbon': 3.6091962319991336e-05,
#  'card': 0.0001804598115999567,
#  'cardboard': 3.6091962319991336e-05,
#  'cardigan': 3.6091962319991336e-05,
#  'cards': 3.6091962319991336e-05,
#  'care': 0.0003609196231999134,
#  'career': 3.6091962319991336e-05,
#  'carefully': 3.6091962319991336e-05,
#  'careless': 0.00010827588695997402,
#  'cares': 7.218392463998267e-05,
#  'carnt': 3.6091962319991336e-05,
#  'carol': 3.6091962319991336e-05,
#  'carrie': 7.218392463998267e-05,
#  'case': 7.218392463998267e-05,
#  'cash': 0.00010827588695997402,
#  'cassadee': 3.6091962319991336e-05,
#  'cat': 0.0001804598115999567,
#  'catch': 3.6091962319991336e-05,
#  'catche': 3.6091962319991336e-05,
#  'category': 3.6091962319991336e-05,
#  'cats': 0.00014436784927996535,
#  'caught': 0.00014436784927996535,
#  'cause': 0.0002526437362399394,
#  'cauzinhoooo': 3.6091962319991336e-05,
#  'cavity': 3.6091962319991336e-05,
#  'cd': 3.6091962319991336e-05,
#  'cecilia': 3.6091962319991336e-05,
#  'celebs': 3.6091962319991336e-05,
#  'cell': 3.6091962319991336e-05,
#  'cert': 3.6091962319991336e-05,
#  'ch': 7.218392463998267e-05,
#  'chai': 3.6091962319991336e-05,
#  'chalky': 3.6091962319991336e-05,
#  'challanges': 3.6091962319991336e-05,
#  'challenge': 3.6091962319991336e-05,
#  'challenged': 3.6091962319991336e-05,
#  'chance': 0.0002887356985599307,
#  'chances': 3.6091962319991336e-05,
#  'change': 3.6091962319991336e-05,
#  'changed': 7.218392463998267e-05,
#  'channel': 3.6091962319991336e-05,
#  'chaos': 3.6091962319991336e-05,
#  'charge': 7.218392463998267e-05,
#  'charged': 3.6091962319991336e-05,
#  'closes': 3.6091962319991336e-05,
#  'closing': 3.6091962319991336e-05,
#  'clot': 3.6091962319991336e-05,
#  'clothes': 3.6091962319991336e-05,
#  'cloudy': 3.6091962319991336e-05,
#  'clown': 3.6091962319991336e-05,
#  'clowns': 3.6091962319991336e-05,
#  'clue': 3.6091962319991336e-05,
#  'clumsy': 3.6091962319991336e-05,
#  'clutter': 3.6091962319991336e-05,
#  'cnt': 0.00010827588695997402,
#  'co': 0.00010827588695997402,
#  'coast': 3.6091962319991336e-05,
#  'cobblestones': 3.6091962319991336e-05,
#  'cod': 3.6091962319991336e-05,
#  'code': 7.218392463998267e-05,
#  'coding': 3.6091962319991336e-05,
#  'coffee': 0.0002887356985599307,
#  'coffeeclub': 3.6091962319991336e-05,
#  'cold': 0.0010105749449597576,
#  'colds': 3.6091962319991336e-05,
#  'collapse': 3.6091962319991336e-05,
#  'collapses': 7.218392463998267e-05,
#  'collection': 7.218392463998267e-05,
#  'college': 7.218392463998267e-05,
#  'com': 0.00014436784927996535,
#  'combined': 3.6091962319991336e-05,
#  'combo': 3.6091962319991336e-05,
#  'come': 0.0007940231710398094,
#  'comes': 0.00010827588695997402,
#  'comfortable': 0.00010827588695997402,
#  'coming': 0.0001804598115999567,
#  'comm': 3.6091962319991336e-05,
#  'commands': 3.6091962319991336e-05,
#  'comment': 3.6091962319991336e-05,
#  'comments': 3.6091962319991336e-05,
#  'company': 7.218392463998267e-05,
#  'competetion': 3.6091962319991336e-05,
#  'competition': 3.6091962319991336e-05,
#  'complain': 7.218392463998267e-05,
#  'complaining': 7.218392463998267e-05,
#  'complete': 7.218392463998267e-05,
#  'completely': 0.0002887356985599307,
#  'complex': 3.6091962319991336e-05,
#  'complicated': 0.0001804598115999567,
#  'compose': 3.6091962319991336e-05,
#  'comps': 3.6091962319991336e-05,
#  'computer': 0.00032482766087992205,
#  'conan': 3.6091962319991336e-05,
#  'concentrate': 7.218392463998267e-05,
#  'concept': 3.6091962319991336e-05,
#  'concert': 7.218392463998267e-05,
#  'condolence': 3.6091962319991336e-05,
#  'confident': 3.6091962319991336e-05,
#  'confirmed': 3.6091962319991336e-05,
#  'conflicts': 3.6091962319991336e-05,
#  'confsuing': 3.6091962319991336e-05,
#  'confuse': 3.6091962319991336e-05,
#  'confused': 0.0002526437362399394,
#  'confusin': 3.6091962319991336e-05,
#  'confusing': 0.00010827588695997402,
#  'confusions': 3.6091962319991336e-05,
#  'conjunctivitis': 3.6091962319991336e-05,
#  'connection': 7.218392463998267e-05,
#  'considerably': 3.6091962319991336e-05,
#  'considering': 3.6091962319991336e-05,
#  'constant': 3.6091962319991336e-05,
#  'constantly': 3.6091962319991336e-05,
#  'contest': 3.6091962319991336e-05,
#  'continually': 3.6091962319991336e-05,
#  'controls': 3.6091962319991336e-05,
#  'convenient': 3.6091962319991336e-05,
#  'conversation': 7.218392463998267e-05,
#  'convinced': 0.00010827588695997402,
#  'cook': 3.6091962319991336e-05,
#  'cool': 0.0003609196231999134,
#  'cooperating': 7.218392463998267e-05,
#  'cope': 7.218392463998267e-05,
#  'cuddle': 7.218392463998267e-05,
#  'current': 3.6091962319991336e-05,
#  'currently': 3.6091962319991336e-05,
#  'curse': 0.00010827588695997402,
#  'cursed': 3.6091962319991336e-05,
#  'cursing': 3.6091962319991336e-05,
#  'cut': 0.0002526437362399394,
#  'cute': 0.00010827588695997402,
#  'cuties': 3.6091962319991336e-05,
#  'cutting': 3.6091962319991336e-05,
#  'cuz': 0.00032482766087992205,
#  'cyberstalking': 3.6091962319991336e-05,
#  'cycle': 3.6091962319991336e-05,
#  'cyclone': 3.6091962319991336e-05,
#  'da': 3.6091962319991336e-05,
#  'daaaaang': 3.6091962319991336e-05,
#  'daaaang': 3.6091962319991336e-05,
#  'daaammmnnnnn': 3.6091962319991336e-05,
#  'dad': 0.00010827588695997402,
#  'dada': 3.6091962319991336e-05,
#  'daddy': 0.00014436784927996535,
#  'dam': 7.218392463998267e-05,
#  'damage': 0.00010827588695997402,
#  'damit': 3.6091962319991336e-05,
#  'damm': 3.6091962319991336e-05,
#  ...}

# %%
# Probabilities of words in neutral sentiment class
prob_t = []
total_t_values = sum(freq_t.values())
for word, count in zip(word_list_t, count_list_t):
    prob_t.append(count / total_t_values)
t_prob_dict = dict(zip(word_list_t, prob_t))

# Probabilities of words in positive sentiment class
prob_p = []
total_p_values = sum(freq_p.values())
for word, count in zip(word_list_p, count_list_p):
    prob_p.append(count / total_p_values)
p_prob_dict = dict(zip(word_list_p, prob_p))

# %% [markdown]
# ## Probability of words in each sentiment class (Part 2)
# - However, as the above equation involves the probabilities of a new word of a new sentence with respect to a sentiment class, if a word for the new sentence does not occur within the sentiment class in the training set, the entire equation will become zero.
# - For example, P(The company is going bankrupt|neutral) = P(The|neutral) * P(company|neutral) * P(is|neutral) * P(going|neutral) * P(bankrupt|neutal) will be equal 0 if any of the probabilities on the right hand side is zero.
# - To fix this problem, we use Laplace Smoothing.

# %%
# Total count of all features in the training set
docs = [row['selected_text'] for index,row in df.iterrows()]

vec = CountVectorizer()
X = vec.fit_transform(docs)

total_features = len(vec.get_feature_names())

# # Total count of individual features in the training set
total_cnts_features_n = count_list_n.sum(axis=0)
total_cnts_features_t = count_list_t.sum(axis=0)
total_cnts_features_p = count_list_p.sum(axis=0)

# %% [markdown]
# ## Combining the probabilities
# - Now, we will be calculating the left hand side of numerator above, before combining with the right hand side of
# the numerator found above, to find the total value of the numerator.
# - To find the left hand side of the numerator, we will multiply the individual word probabilities, applying Laplace Smoothing.
# - The right hand side of the numerator is found above, which is simply the probabilities of each fo the sentiment classes.
# - We combine the left and right hand sides of the numerator to find the total value of the numerator, which are:
#  1. [P(The company is going bankrupt|neutral) * P(neutral)]
#  2. [P(The company is going bankrupt|positive) * P(positive)]
#  3. [P(The company is going bankrupt|negative) * P(negative)]
# - As mentioned above, since the denominators are all the same and can be ignored, we can compare the numerators above to find which of these probabilities are the largest(hence most likely to be the correct sentiment):
#  1. P(neutral|The company is going bankrupt)
#  2. P(positive|The company is going bankrupt)
#  3. P(negative|The company is going bankrupt)
# - As seen below, since P(negative|The company is going bankrupt) is the largest, it is most likely that the sentiment is negative, given the sentence "The company is going bankrupt", hence we conclude that the sentiment is negative.

# %%
from nltk.tokenize import word_tokenize
# Tokenize the new_sentence, which is the sentence we would like the predict the sentiment of.
new_sentence = 'The company is going bankrupt'
new_word_list = word_tokenize(new_sentence)
new_word_list
# Out:
# ['The', 'company', 'is', 'going', 'bankrupt']

# %%
# P(The company is going bankrupt|negative) = P(The|negative) * P(company|negative) * P(is|negative) * P(going|negative) * P(bankrupt|negative)
# To find P(The company is going bankrupt|negative), multiply the individual word probabilities
prob_n_with_ls = []
for word in new_word_list:
    if word in freq_n.keys():
        count = freq_n[word]
    else:
        count = 0
    prob_n_with_ls.append((count + 1)/(total_cnts_features_n + total_features))
dict_n_dict = dict(zip(new_word_list,prob_n_with_ls))
print(dict_n_dict)
n_prob_left = 1
for key in dict_n_dict:    
    n_prob_left = n_prob_left * dict_n_dict[key]
n_prob_left
# Out:
# {'The': 2.2061905707415006e-05, 'company': 6.618571712224501e-05, 'is': 0.008273214640280628, 'going': 0.0017428905508857855, 'bankrupt': 2.2061905707415006e-05}
# 4.645096429746363e-19

# %%
# Now, we just need to find the value of the entire numerator of the negative sentiment class
# [P(The company is going bankrupt|negative) * P(negative)]
n_prob_total = n_prob_left * negative_prob
n_prob_total
# Out:
# 1.315265477432913e-19

# %%
# Repeat this for the neutral and positive sentiment classes

# P(The company is going bankrupt|neutral) = P(The|neutral) * P(company|neutral) * P(is|neutral) * P(going|neutral) * P(bankrupt|neutral)
# To find P(The company is going bankrupt|neutral), multiply the individual word probabilities
prob_t_with_ls = []
for word in new_word_list:
    if word in freq_t.keys():
        count = freq_t[word]
    else:
        count = 0
    prob_t_with_ls.append((count + 1)/(total_cnts_features_t + total_features))
dict_t_dict = dict(zip(new_word_list,prob_t_with_ls))
print(dict_t_dict)
t_prob_left = 1
for key in dict_t_dict:    
    t_prob_left = t_prob_left * dict_t_dict[key]

    
# Now, we just need to find the value of the entire numerator of the neutral sentiment class
# [P(The company is going bankrupt|neutral) * P(neutral)]
t_prob_total = t_prob_left * neutral_prob
t_prob_total
# Out:
# {'The': 7.00883814490072e-06, 'company': 0.00013316792475311366, 'is': 0.010408124645177569, 'going': 0.0033432157951176432, 'bankrupt': 7.00883814490072e-06}
# 9.208724189362161e-20

# %%
# P(The company is going bankrupt|positive) = P(The|positive) * P(company|positive) * P(is|positive) * P(going|positive) * P(bankrupt|positive)
# To find P(The company is going bankrupt|positive), multiply the individual word probabilities
prob_p_with_ls = []
for word in new_word_list:
    if word in freq_p.keys():
        count = freq_p[word]
    else:
        count = 0
    prob_p_with_ls.append((count + 1)/(total_cnts_features_p + total_features))
dict_p_dict = dict(zip(new_word_list,prob_p_with_ls))
print(dict_p_dict)
p_prob_left = 1
for key in dict_p_dict:    
    p_prob_left = p_prob_left * dict_p_dict[key]

    
# Now, we just need to find the value of the entire numerator of the positive sentiment class
# [P(The company is going bankrupt|positive) * P(positive)]
p_prob_total = p_prob_left * positive_prob
p_prob_total
# Out:
# {'The': 2.2107264447097318e-05, 'company': 8.842905778838927e-05, 'is': 0.006057390458504665, 'going': 0.0009727196356722819, 'bankrupt': 2.2107264447097318e-05}
# 7.952616574025986e-20

# %%
p_prob_total = p_prob_left * positive_prob
cur_max_sentiment = "negative"
cur_max_num = n_prob_total

if t_prob_total > cur_max_num:
    cur_max_sentiment = "neutral"
    cur_max_num = t_prob_total
if p_prob_total > cur_max_num:
    cur_max_sentiment = "positive"
    cur_max_num = p_prob_total

print("Positive: " + str(p_prob_total))
print("Negative: " + str(n_prob_total))
print("Neutral: " + str(t_prob_total) + "\n")

print("Sentence: " + new_sentence)
print("Predicted Sentiment: " + cur_max_sentiment)
# Out:
# Positive: 7.952616574025986e-20
# Negative: 1.315265477432913e-19
# Neutral: 9.208724189362161e-20
#
# Sentence: The company is going bankrupt
# Predicted Sentiment: negative

# %% [markdown]
# ## Custom sentiment prediction
# - Now, let us place the entire section above into a function in order to make predictions for a custom sentence.
# - The code in this function is the same as above.
# - Have fun making your own predictions based on the dataset!! Change the sentence_to_be_predicted value.

# %%
def predict(my_sentence):
    # Tokenize the new_sentence, which is the sentence we would like the predict the sentiment of.
    new_word_list = word_tokenize(my_sentence)
    
    ## NEGATIVE sentiment
    prob_n_with_ls = []
    for word in new_word_list:
        if word in freq_n.keys():
            count = freq_n[word]
        else:
            count = 0
        prob_n_with_ls.append((count + 1)/(total_cnts_features_n + total_features))
    dict_n_dict = dict(zip(new_word_list,prob_n_with_ls))
    n_prob_left = 1
    for key in dict_n_dict:    
        n_prob_left = n_prob_left * dict_n_dict[key]
    n_prob_total = n_prob_left * negative_prob
    
    ## NEUTRAL sentiment
    prob_t_with_ls = []
    for word in new_word_list:
        if word in freq_t.keys():
            count = freq_t[word]
        else:
            count = 0
        prob_t_with_ls.append((count + 1)/(total_cnts_features_t + total_features))
    dict_t_dict = dict(zip(new_word_list,prob_t_with_ls))
    t_prob_left = 1
    for key in dict_t_dict:    
        t_prob_left = t_prob_left * dict_t_dict[key]

    t_prob_total = t_prob_left * neutral_prob
    
    ## POSITIVE sentiment
    prob_p_with_ls = []
    for word in new_word_list:
        if word in freq_p.keys():
            count = freq_p[word]
        else:
            count = 0
        prob_p_with_ls.append((count + 1)/(total_cnts_features_p + total_features))
    dict_p_dict = dict(zip(new_word_list,prob_p_with_ls))
    p_prob_left = 1
    for key in dict_p_dict:    
        p_prob_left = p_prob_left * dict_p_dict[key]
        
    p_prob_total = p_prob_left * positive_prob
    cur_max_sentiment = "negative"
    cur_max_num = n_prob_total
    
    if t_prob_total > cur_max_num:
        cur_max_sentiment = "neutral"
        cur_max_num = t_prob_total
    if p_prob_total > cur_max_num:
        cur_max_sentiment = "positive"
        cur_max_num = p_prob_total
    
    print("Positive: " + str(p_prob_total))
    print("Negative: " + str(n_prob_total))
    print("Neutral: " + str(t_prob_total) + "\n")
    
    print("Predicted Sentiment: " + cur_max_sentiment)

# %%
sentence_to_be_predicted = "this is difficult"
predict(sentence_to_be_predicted)
# Out:
# Positive: 1.7011600944603131e-10
# Negative: 1.3864767838425653e-09
# Neutral: 5.967346292592119e-10
#
# Predicted Sentiment: negative
